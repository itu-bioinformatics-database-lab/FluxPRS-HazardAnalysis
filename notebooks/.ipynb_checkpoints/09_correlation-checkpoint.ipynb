# %%
import sys, os
from pathlib import Path
import warnings 
warnings.filterwarnings("ignore")

# --- robust project root detection ---
CWD = Path.cwd()
PROJECT_ROOT = next((p for p in [CWD] + list(CWD.parents) if (p / "preprocessing").exists()), None)
if PROJECT_ROOT is None:
    raise RuntimeError("Could not find PROJECT_ROOT (no 'preprocessing/' directory found in parents).")

# Make imports work + ensure relative paths are consistent
sys.path.insert(0, str(PROJECT_ROOT))
os.chdir(PROJECT_ROOT)

print("CWD:", CWD)
print("PROJECT_ROOT:", PROJECT_ROOT)

import pandas as pd
from sqlalchemy.dialects.mssql.information_schema import columns

from analysis.metabolite_level_analysis import (
    analyse_with_logistic_regression,
    calculate_odds_ratio,
    calculate_hazard_ratio,
    prepare_duration,
    create_ages_df,
    create_ages_df_with_df
)

from preprocessing import (
    MetaboliteLevelsPreprocessorFactory,
    PathwayPreprocessorFactory,
    ReactionPreprocessorFactory,
    MetabolitePathwayCombinedPreprocessorFactory,
    MetaboliteReactionCombinedPreprocessorFactory,
    TranscriptomicsPreprocessorFactory,
    TranscriptomicsMetabolitePreprocessorFactory,
    TranscriptomicsPathwayPreprocessorFactory,
    TranscriptomicsReactionPreprocessorFactory
)
# Out:
# CWD: /home/bioinformatics/Desktop/alzheimer_analysis
# PROJECT_ROOT: /home/bioinformatics/Desktop/alzheimer_analysis

# %%
from analysis.cox_regression import compute_hazard_ratios
from analysis import calculate_risk_score_with_best_prs
import pandas as pd
from sklearn.preprocessing import StandardScaler

from analysis.config import make_default_paths
# dataset root
DATA_DIR = PROJECT_ROOT / "ROSMAP-AD"
paths = make_default_paths(DATA_DIR)

print("PROJECT_ROOT:", PROJECT_ROOT)
print("DATA_DIR:", DATA_DIR)
metabolite_levels_file_path = paths.metabolite_levels_file_path

prs_combined = paths.prs_combined_path
pathway_file_path = paths.pathway_file_path
reaction_file_path = paths.reaction_file_path
metabolite_level_pathway_combined_file_path = paths.metabolite_level_pathway_combined_file_path
metabolite_level_reaction_combined_file_path = paths.metabolite_level_reaction_combined_file_path
x_pathway_path = paths.x_pathway_path
x_reaction_path = paths.x_reaction_path
best_prs_path = paths.best_prs_path
clinical_ages_path = paths.clinical_ages_path

factory_list = [
    MetaboliteLevelsPreprocessorFactory(metabolite_levels_file_path),
    PathwayPreprocessorFactory(metabolite_levels_file_path, pathway_file_path, x_pathway_path),
    ReactionPreprocessorFactory(metabolite_levels_file_path, reaction_file_path, x_reaction_path),
    MetabolitePathwayCombinedPreprocessorFactory(metabolite_levels_file_path, metabolite_level_pathway_combined_file_path, x_pathway_path),
    MetaboliteReactionCombinedPreprocessorFactory(metabolite_levels_file_path, metabolite_level_reaction_combined_file_path, x_reaction_path),
]

general_df = pd.DataFrame()
for factory in factory_list:
    preprocessor = factory.create_preprocessor()
    y, risk_scores, sample_ids_ = analyse_with_logistic_regression(preprocessor)
    biomarker_df = pd.DataFrame({
        preprocessor.name: risk_scores,
        'sample_id': sample_ids_
    })
    if 'sample_id' not in general_df.columns:
        general_df['sample_id'] = sample_ids_

    general_df = pd.merge(general_df, biomarker_df, on='sample_id')

    combined_risk_df = calculate_risk_score_with_best_prs(y, risk_scores, sample_ids_, best_prs_path, prs_combined)
    combined_risk_df = combined_risk_df[['sample_id_biomarker', 'combined_score']]
    combined_risk_df.rename(columns={'combined_score': f"{preprocessor.name} PRS", 'sample_id_biomarker': 'sample_id'}, inplace=True)
    general_df = pd.merge(general_df, combined_risk_df, on='sample_id', how='inner')

prs_df = pd.read_csv(best_prs_path)
prs_df.rename(columns={'score': 'PRS'}, inplace=True)
scaler = StandardScaler()
prs_df["PRS"] = scaler.fit_transform(prs_df[["PRS"]])

general_df = pd.merge(general_df, prs_df, on='sample_id', how='inner')
general_df.to_csv('ROSMAP-AD/processed/general_df_2.csv', index=False)
# Out:
# PROJECT_ROOT: /home/bioinformatics/Desktop/alzheimer_analysis
# DATA_DIR: /home/bioinformatics/Desktop/alzheimer_analysis/ROSMAP-AD

# %%
import seaborn as sns
import matplotlib.pyplot as plt

general_df = general_df.drop(columns=['sample_id'])
print(general_df.columns)
corr = general_df.corr()

# Plot correlation heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Heatmap of Metabolic and Genetic Metrics")
plt.show()
# Out:
# Index(['Metabolite Levels', 'Metabolite Levels PRS', 'Pathway Diff Scores',
#        'Pathway Diff Scores PRS', 'Reaction Diff Scores',
#        'Reaction Diff Scores PRS', 'Metabolite Levels Pathway Combined',
#        'Metabolite Levels Pathway Combined PRS',
#        'Metabolite Levels Reaction Combined',
#        'Metabolite Levels Reaction Combined PRS', 'PRS'],
#       dtype='str')

# %%
from analysis.cox_regression import compute_hazard_ratios
from analysis import calculate_risk_score_with_best_prs
import pandas as pd
from analysis import calculate_risk_score_with_prs
from sklearn.preprocessing import StandardScaler
import os
import glob

# Path to the main folder
main_folder = 'ROSMAP-AD/Final_Prs_Scores'

df_dict = {}
for subfolder in os.listdir(main_folder):
    subfolder_path = os.path.join(main_folder, subfolder)
    general_df = pd.DataFrame()
    if os.path.isdir(subfolder_path):
        prs_id = subfolder
        csv_path = os.path.join(subfolder_path, 'prs_scores.csv')
        prs_scores = pd.read_csv(csv_path)               # Contains individual IDs and scores
        rosmap_clinical = pd.read_csv('ROSMAP-AD/raw/clinical.csv')     # Contains ID, Study, and projid

        # Merge on individual ID
        rosmap_clinical['sample_id'] = rosmap_clinical['Sample ID'].astype(str)
        merged = prs_scores.merge(rosmap_clinical, on='sample_id', how='inner')
        prs_df = merged[['sample_id', 'score']]

        for factory in factory_list:
            preprocessor = factory.create_preprocessor()
            y, risk_scores, sample_ids_ = analyse_with_logistic_regression(preprocessor)
            biomarker_df = pd.DataFrame({
                preprocessor.name: risk_scores,
                'sample_id': sample_ids_
            })
            if 'sample_id' not in general_df.columns:
                general_df['sample_id'] = sample_ids_

            general_df = pd.merge(general_df, biomarker_df, on='sample_id')

            combined_risk_df = calculate_risk_score_with_prs(y, risk_scores, sample_ids_, prs_df, prs_combined)
            combined_risk_df = combined_risk_df[['sample_id_biomarker', 'combined_score']]
            combined_risk_df.rename(columns={'combined_score': f"{preprocessor.name} PRS", 'sample_id_biomarker': 'sample_id'}, inplace=True)
            general_df = pd.merge(general_df, combined_risk_df, on='sample_id', how='inner')

        prs_df = pd.read_csv(best_prs_path)
        prs_df.rename(columns={'score': 'PRS'}, inplace=True)
        scaler = StandardScaler()
        prs_df["PRS"] = scaler.fit_transform(prs_df[["PRS"]])

        general_df = pd.merge(general_df, prs_df, on='sample_id', how='inner')
        general_df.to_csv('ROSMAP-AD/processed/general_df_2.csv', index=False)
        df_dict[subfolder] = general_df
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 29
#      27 for factory in factory_list:
#      28     preprocessor = factory.create_preprocessor()
# ---> 29     y, risk_scores, sample_ids_ = analyse_with_logistic_regression(preprocessor)
#      30     biomarker_df = pd.DataFrame({
#      31         preprocessor.name: risk_scores,
#      32         'sample_id': sample_ids_
#      33     })
#      34     if 'sample_id' not in general_df.columns:
#
# File ~/Desktop/alzheimer_analysis/analysis/metabolite_level_analysis.py:12, in analyse_with_logistic_regression(preprocessor)
#       9 def analyse_with_logistic_regression(
#      10         preprocessor: Preprocessor
#      11 ):
# ---> 12     preprocessor.transform_custom_file()
#      13     metabolite_levels, sample_ids, order_index = preprocessor.prepare_df()
#      16     x = metabolite_levels.drop(columns=['Diagnosis'])
#
# File ~/Desktop/alzheimer_analysis/preprocessing/Preprocessor.py:119, in MetaboliteReactionCombinedPreprocessor.transform_custom_file(self)
#     117 reaction_df = reaction_df.iloc[:, 1:]
#     118 combined_df = pd.concat([metabolite_levels_df, reaction_df], axis=1)
# --> 119 combined_df.to_csv(self.file_path, index=False, sep=",")
#
# File ~/anaconda3/envs/pgs/lib/python3.11/site-packages/pandas/core/generic.py:3988, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3977 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3979 formatter = DataFrameFormatter(
#    3980     frame=df,
#    3981     header=header,
#    (...)   3985     decimal=decimal,
#    3986 )
# -> 3988 return DataFrameRenderer(formatter).to_csv(
#    3989     path_or_buf,
#    3990     lineterminator=lineterminator,
#    3991     sep=sep,
#    3992     encoding=encoding,
#    3993     errors=errors,
#    3994     compression=compression,
#    3995     quoting=quoting,
#    3996     columns=columns,
#    3997     index_label=index_label,
#    3998     mode=mode,
#    3999     chunksize=chunksize,
#    4000     quotechar=quotechar,
#    4001     date_format=date_format,
#    4002     doublequote=doublequote,
#    4003     escapechar=escapechar,
#    4004     storage_options=storage_options,
#    4005 )
#
# File ~/anaconda3/envs/pgs/lib/python3.11/site-packages/pandas/io/formats/format.py:1025, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1004     created_buffer = False
#    1006 csv_formatter = CSVFormatter(
#    1007     path_or_buf=path_or_buf,
#    1008     lineterminator=lineterminator,
#    (...)   1023     formatter=self.fmt,
#    1024 )
# -> 1025 csv_formatter.save()
#    1027 if created_buffer:
#    1028     assert isinstance(path_or_buf, StringIO)
#
# File ~/anaconda3/envs/pgs/lib/python3.11/site-packages/pandas/io/formats/csvs.py:272, in CSVFormatter.save(self)
#     251 with get_handle(
#     252     self.filepath_or_buffer,
#     253     self.mode,
#    (...)    260     # error: Argument "quoting" to "writer" has incompatible type "int";
#     261     # expected "Literal[0, 1, 2, 3]"
#     262     self.writer = csvlib.writer(
#     263         handles.handle,
#     264         lineterminator=self.lineterminator,
#    (...)    269         quotechar=self.quotechar,
#     270     )
# --> 272     self._save()
#
# File ~/anaconda3/envs/pgs/lib/python3.11/site-packages/pandas/io/formats/csvs.py:277, in CSVFormatter._save(self)
#     275 if self._need_to_save_header:
#     276     self._save_header()
# --> 277 self._save_body()
#
# File ~/anaconda3/envs/pgs/lib/python3.11/site-packages/pandas/io/formats/csvs.py:315, in CSVFormatter._save_body(self)
#     313 if start_i >= end_i:
#     314     break
# --> 315 self._save_chunk(start_i, end_i)
#
# File ~/anaconda3/envs/pgs/lib/python3.11/site-packages/pandas/io/formats/csvs.py:322, in CSVFormatter._save_chunk(self, start_i, end_i)
#     319 slicer = slice(start_i, end_i)
#     320 df = self.obj.iloc[slicer]
# --> 322 res = df._get_values_for_csv(**self._number_format)
#     323 data = list(res._iter_column_arrays())
#     325 ix = (
#     326     self.data_index[slicer]._get_values_for_csv(**self._number_format)
#     327     if self.nlevels != 0
#     328     else np.empty(end_i - start_i)
#     329 )
#
# File ~/anaconda3/envs/pgs/lib/python3.11/site-packages/pandas/core/frame.py:1396, in DataFrame._get_values_for_csv(self, float_format, date_format, decimal, na_rep, quoting)
#    1386 def _get_values_for_csv(
#    1387     self,
#    1388     *,
#    (...)   1394 ) -> DataFrame:
#    1395     # helper used by to_csv
# -> 1396     mgr = self._mgr.get_values_for_csv(
#    1397         float_format=float_format,
#    1398         date_format=date_format,
#    1399         decimal=decimal,
#    1400         na_rep=na_rep,
#    1401         quoting=quoting,
#    1402     )
#    1403     return self._constructor_from_mgr(mgr, axes=mgr.axes)
#
# File ~/anaconda3/envs/pgs/lib/python3.11/site-packages/pandas/core/internals/managers.py:626, in BaseBlockManager.get_values_for_csv(self, float_format, date_format, decimal, na_rep, quoting)
#     619 def get_values_for_csv(
#     620     self, *, float_format, date_format, decimal, na_rep: str = "nan", quoting=None
#     621 ) -> Self:
#     622     """
#     623     Convert values to native types (strings / python objects) that are used
#     624     in formatting (repr / csv).
#     625     """
# --> 626     return self.apply(
#     627         "get_values_for_csv",
#     628         na_rep=na_rep,
#     629         quoting=quoting,
#     630         float_format=float_format,
#     631         date_format=date_format,
#     632         decimal=decimal,
#     633     )
#
# File ~/anaconda3/envs/pgs/lib/python3.11/site-packages/pandas/core/internals/managers.py:442, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     440         applied = b.apply(f, **kwargs)
#     441     else:
# --> 442         applied = getattr(b, f)(**kwargs)
#     443     result_blocks = extend_blocks(applied, result_blocks)
#     445 out = type(self).from_blocks(result_blocks, [ax.view() for ax in self.axes])
#
# File ~/anaconda3/envs/pgs/lib/python3.11/site-packages/pandas/core/internals/blocks.py:637, in Block.get_values_for_csv(self, float_format, date_format, decimal, na_rep, quoting)
#     628 """convert to our native types format"""
#     629 result = get_values_for_csv(
#     630     self.values,
#     631     na_rep=na_rep,
#    (...)    635     decimal=decimal,
#     636 )
# --> 637 return self.make_block(result)
#
# File ~/anaconda3/envs/pgs/lib/python3.11/site-packages/pandas/core/internals/blocks.py:244, in Block.make_block(self, values, placement, refs)
#     241 if self.is_extension:
#     242     values = ensure_block_shape(values, ndim=self.ndim)
# --> 244 return new_block(values, placement=placement, ndim=self.ndim, refs=refs)
#
# File ~/anaconda3/envs/pgs/lib/python3.11/site-packages/pandas/core/internals/blocks.py:2270, in new_block(values, placement, ndim, refs)
#    2258 def new_block(
#    2259     values,
#    2260     placement: BlockPlacement,
#    (...)   2267     # - check_ndim/ensure_block_shape already checked
#    2268     # - maybe_coerce_values already called/unnecessary
#    2269     klass = get_block_type(values.dtype)
# -> 2270     return klass(values, ndim=ndim, placement=placement, refs=refs)
#
# KeyboardInterrupt:

# %%
import seaborn as sns
import matplotlib.pyplot as plt

for subfolder in os.listdir(main_folder):
    if subfolder == '.DS_Store':
        continue
    df = df_dict[subfolder]
    df = df.drop(columns=['sample_id'])
    corr = df.corr()

    # Plot correlation heatmap
    plt.figure(figsize=(10, 8))
    sns.heatmap(corr, annot=True, cmap='coolwarm', fmt=".2f")
    plt.title(f"Correlation Heatmap of Metabolic Metrics and {subfolder}")
    plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels
    plt.yticks(rotation=0)               # Keep y-axis labels horizontal
    plt.tight_layout()  # Adjust layout to fit everything nicely
    output_path = os.path.join("plots/heatmaps", f"correlation_heatmap{subfolder}.png")
    os.makedirs(os.path.dirname(output_path), exist_ok=True)
    plt.savefig(output_path, dpi=300, facecolor='white')  # Save with white background
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[13], line 7
#       5 if subfolder == '.DS_Store':
#       6     continue
# ----> 7 df = df_dict[subfolder]
#       8 df = df.drop(columns=['sample_id'])
#       9 corr = df.corr()
#
# KeyError: 'PGS001349'
